# %%
# !pkill -f streamlit || true
# !pkill -f cloudflared || true
# !rm -f streamlit.log app.py

# micromamba
# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# !./bin/micromamba --version

# cloudflared
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !./cloudflared --version
# Out:
# ^C
# ^C
# bin/micromamba
# 2.5.0
# cloudflared version 2026.1.2 (built 2026-01-27-11:31 UTC)

# %%
# !./bin/micromamba env remove -n vaexenv -y || true

# Cài mọi thứ bằng conda-forge để khỏi bị lỗi build pyyaml
# !./bin/micromamba create -y -n vaexenv -c conda-forge \
  python=3.10 vaex streamlit pandas plotly pyyaml "pydantic<2"

# Test
# !./bin/micromamba run -n vaexenv python -c "import vaex, pydantic, yaml, streamlit; \
print('vaex', vaex.__version__); print('pydantic', pydantic.__version__); print('yaml OK'); print('streamlit', streamlit.__version__)"
# Out:
# info     libmamba ****************** Backtrace Start ******************
# debug    libmamba Loading configuration
# trace    libmamba Compute configurable 'create_base'
# trace    libmamba Compute configurable 'no_env'
# trace    libmamba Compute configurable 'no_rc'
# trace    libmamba Compute configurable 'rc_files'
# trace    libmamba Compute configurable 'root_prefix'
# trace    libmamba Get RC files configuration from locations up to HomeDir
# trace    libmamba Configuration not found at '/root/.mambarc'
# trace    libmamba Configuration not found at '/root/.mamba/mambarc.d'
# trace    libmamba Configuration not found at '/root/.mamba/mambarc'
# trace    libmamba Configuration not found at '/root/.mamba/.mambarc'
# trace    libmamba Configuration not found at '/root/.config/mamba/mambarc.d'
# trace    libmamba Configuration not found at '/root/.config/mamba/mambarc'
# trace    libmamba Configuration not found at '/root/.config/mamba/.mambarc'
# trace    libmamba Configuration not found at '/root/.condarc'
# trace    libmamba Configuration not found at '/root/.conda/condarc.d'
# trace    libmamba Configuration not found at '/root/.conda/condarc'
# trace    libmamba Configuration not found at '/root/.conda/.condarc'
# trace    libmamba Configuration not found at '/root/.config/conda/condarc.d'
# trace    libmamba Configuration not found at '/root/.config/conda/condarc'
# trace    libmamba Configuration not found at '/root/.config/conda/.condarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/.mambarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/condarc.d'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/condarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/.condarc'
# trace    libmamba Configuration not found at '/var/lib/conda/.mambarc'
# trace    libmamba Configuration not found at '/var/lib/conda/condarc.d/'
# trace    libmamba Configuration not found at '/var/lib/conda/condarc'
# trace    libmamba Configuration not found at '/var/lib/conda/.condarc'
# trace    libmamba Configuration not found at '/etc/conda/.mambarc'
# trace    libmamba Configuration not found at '/etc/conda/condarc.d/'
# trace    libmamba Configuration not found at '/etc/conda/condarc'
# trace    libmamba Configuration not found at '/etc/conda/.condarc'
# trace    libmamba Update configurable 'no_env'
# trace    libmamba Compute configurable 'envs_dirs'
# trace    libmamba Compute configurable 'file_specs'
# trace    libmamba Compute configurable 'spec_file_env_name'
# trace    libmamba Compute configurable 'env_name'
# trace    libmamba Compute configurable 'use_default_prefix_fallback'
# trace    libmamba Compute configurable 'use_root_prefix_fallback'
# trace    libmamba Compute configurable 'use_target_prefix_fallback'
# trace    libmamba Compute configurable 'target_prefix'
# trace    libmamba Get RC files configuration from locations up to TargetPrefix
# trace    libmamba Configuration not found at '/root/.local/share/mamba/envs/vaexenv/.mambarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/envs/vaexenv/condarc.d'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/envs/vaexenv/condarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/envs/vaexenv/.condarc'
# trace    libmamba Configuration not found at '/root/.mambarc'
# trace    libmamba Configuration not found at '/root/.mamba/mambarc.d'
# trace    libmamba Configuration not found at '/root/.mamba/mambarc'
# trace    libmamba Configuration not found at '/root/.mamba/.mambarc'
# trace    libmamba Configuration not found at '/root/.config/mamba/mambarc.d'
# trace    libmamba Configuration not found at '/root/.config/mamba/mambarc'
# trace    libmamba Configuration not found at '/root/.config/mamba/.mambarc'
# trace    libmamba Configuration not found at '/root/.condarc'
# trace    libmamba Configuration not found at '/root/.conda/condarc.d'
# trace    libmamba Configuration not found at '/root/.conda/condarc'
# trace    libmamba Configuration not found at '/root/.conda/.condarc'
# trace    libmamba Configuration not found at '/root/.config/conda/condarc.d'
# trace    libmamba Configuration not found at '/root/.config/conda/condarc'
# trace    libmamba Configuration not found at '/root/.config/conda/.condarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/.mambarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/condarc.d'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/condarc'
# trace    libmamba Configuration not found at '/root/.local/share/mamba/.condarc'
# trace    libmamba Configuration not found at '/var/lib/conda/.mambarc'
# trace    libmamba Configuration not found at '/var/lib/conda/condarc.d/'
# trace    libmamba Configuration not found at '/var/lib/conda/condarc'
# trace    libmamba Configuration not found at '/var/lib/conda/.condarc'
# trace    libmamba Configuration not found at '/etc/conda/.mambarc'
# trace    libmamba Configuration not found at '/etc/conda/condarc.d/'
# trace    libmamba Configuration not found at '/etc/conda/condarc'
# trace    libmamba Configuration not found at '/etc/conda/.condarc'
# trace    libmamba Update configurable 'no_env'
# trace    libmamba Compute configurable 'relocate_prefix'
# trace    libmamba Compute configurable 'target_prefix_checks'
# error    libmamba No prefix found at: /root/.local/share/mamba/envs/vaexenv
# error    libmamba Environment must first be created with "micromamba create -n {env_name} ..."
# critical libmamba Aborting.
# info     libmamba ****************** Backtrace End ********************
# [+] 0.0s
# [+] 0.1s
# [+] 0.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    12%[+] 0.3s
# conda-forge/linux-64   2%
# conda-forge/noarch    38%[+] 0.4s
# conda-forge/linux-64   7%
# conda-forge/noarch    64%[+] 0.5s
# conda-forge/linux-64  13%
# conda-forge/noarch    76%[+] 0.6s
# conda-forge/linux-64  17%
# conda-forge/noarch    86%[+] 0.7s
# conda-forge/linux-64  24%
# conda-forge/noarch    99%conda-forge/noarch
# [+] 0.8s
# conda-forge/linux-64  32%[+] 0.9s
# conda-forge/linux-64  41%[+] 1.0s
# conda-forge/linux-64  55%[+] 1.1s
# conda-forge/linux-64  64%[+] 1.2s
# conda-forge/linux-64  69%[+] 1.3s
# conda-forge/linux-64  78%[+] 1.4s
# conda-forge/linux-64  86%[+] 1.5s
# conda-forge/linux-64  93%[+] 1.6s
# conda-forge/linux-64  99%conda-forge/linux-64
#
#
# Transaction
#
#   Prefix: /root/.local/share/mamba/envs/vaexenv
#
#   Updating specs:
#
#    - python=3.10
#    - vaex
#    - streamlit
#    - pandas
#    - plotly
#    - pyyaml
#    - pydantic<2
#
#
#   Package                                         Version  Build                    Channel          Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                                     0.1  conda_forge              conda-forge       3kB
#   + _openmp_mutex                                     4.5  2_gnu                    conda-forge      24kB
#   + altair                                          6.0.0  pyhd8ed1ab_1             conda-forge     566kB
#   + annotated-doc                                   0.0.4  pyhcf101f3_0             conda-forge      14kB
#   + anyio                                          4.12.1  pyhcf101f3_0             conda-forge     145kB
#   + aplus                                          0.11.0  py_1                     conda-forge       6kB
#   + argon2-cffi                                    25.1.0  pyhd8ed1ab_0             conda-forge      19kB
#   + argon2-cffi-bindings                           25.1.0  py310h7c4b9e2_2          conda-forge      35kB
#   + arrow                                           1.4.0  pyhcf101f3_0             conda-forge     114kB
#   + astropy                                         6.1.7  py310hf462985_0          conda-forge       8MB
#   + astropy-iers-data                 0.2026.1.26.0.43.56  pyhd8ed1ab_0             conda-forge       1MB
#   + asttokens                                       3.0.1  pyhd8ed1ab_0             conda-forge      29kB
#   + async-lru                                       2.1.0  pyhcf101f3_0             conda-forge      19kB
#   + attrs                                          25.4.0  pyhcf101f3_1             conda-forge      65kB
#   + aws-c-auth                                      0.9.3  hef928c7_0               conda-forge     133kB
#   + aws-c-cal                                      0.9.13  h2c9d079_1               conda-forge      56kB
#   + aws-c-common                                   0.12.6  hb03c661_0               conda-forge     240kB
#   + aws-c-compression                               0.3.1  h8b1a151_9               conda-forge      22kB
#   + aws-c-event-stream                              0.5.7  h28f887f_1               conda-forge      59kB
#   + aws-c-http                                     0.10.7  ha8fc4e3_5               conda-forge     225kB
#   + aws-c-io                                       0.23.3  hdaf4b65_5               conda-forge     181kB
#   + aws-c-mqtt                                     0.13.3  hc63082f_11              conda-forge     216kB
#   + aws-c-s3                                       0.11.3  h06ab39a_1               conda-forge     151kB
#   + aws-c-sdkutils                                  0.2.4  h8b1a151_4               conda-forge      59kB
#   + aws-checksums                                   0.2.7  h8b1a151_5               conda-forge      77kB
#   + aws-crt-cpp                                    0.35.4  h8824e59_0               conda-forge     409kB
#   + aws-sdk-cpp                                  1.11.606  h20b40b1_10              conda-forge       3MB
#   + azure-core-cpp                                 1.16.1  h3a458e0_0               conda-forge     348kB
#   + azure-identity-cpp                             1.13.2  h3a5f585_1               conda-forge     250kB
#   + azure-storage-blobs-cpp                       12.16.0  h75daedc_0               conda-forge     580kB
#   + azure-storage-common-cpp                      12.12.0  h3d7a050_0               conda-forge     150kB
#   + azure-storage-files-datalake-cpp              12.14.0  hd454692_0               conda-forge     302kB
#   + babel                                          2.17.0  pyhd8ed1ab_0             conda-forge       7MB
#   + backports.zstd                                  1.3.0  py310h69bd2ac_0          conda-forge     191kB
#   + beautifulsoup4                                 4.14.3  pyha770c72_0             conda-forge      90kB
#   + blake3                                          1.0.8  py310hd8f68c5_1          conda-forge     387kB
#   + bleach                                          6.3.0  pyhcf101f3_0             conda-forge     142kB
#   + bleach-with-css                                 6.3.0  h5f6438b_0               conda-forge       4kB
#   + blinker                                         1.9.0  pyhff2d567_0             conda-forge      14kB
#   + bokeh                                           3.8.2  pyhd8ed1ab_0             conda-forge       5MB
#   + bqplot                                        0.12.45  pyhe01879c_0             conda-forge     966kB
#   + branca                                          0.8.2  pyhd8ed1ab_0             conda-forge      30kB
#   + brotli                                          1.2.0  hed03a55_1               conda-forge      20kB
#   + brotli-bin                                      1.2.0  hb03c661_1               conda-forge      21kB
#   + brotli-python                                   1.2.0  py310hba01987_1          conda-forge     367kB
#   + bzip2                                           1.0.8  hda65f42_8               conda-forge     260kB
#   + c-ares                                         1.34.6  hb03c661_0               conda-forge     208kB
#   + ca-certificates                              2026.1.4  hbd8a1cb_0               conda-forge     147kB
#   + cached-property                                 1.5.2  hd8ed1ab_1               conda-forge       4kB
#   + cached_property                                 1.5.2  pyha770c72_1             conda-forge      11kB
#   + cachetools                                      6.2.6  pyhd8ed1ab_0             conda-forge      17kB
#   + certifi                                      2026.1.4  pyhd8ed1ab_0             conda-forge     151kB
#   + cffi                                            2.0.0  py310he7384ee_1          conda-forge     245kB
#   + charset-normalizer                              3.4.4  pyhd8ed1ab_0             conda-forge      51kB
#   + click                                           8.3.1  pyh8f84b5b_1             conda-forge      98kB
#   + cloudpickle                                     3.1.2  pyhcf101f3_1             conda-forge      27kB
#   + comm                                            0.2.3  pyhe01879c_0             conda-forge      15kB
#   + contourpy                                       1.3.2  py310h3788b33_0          conda-forge     261kB
#   + cycler                                         0.12.1  pyhcf101f3_2             conda-forge      15kB
#   + cytoolz                                         1.1.0  py310h7c4b9e2_1          conda-forge     565kB
#   + dask                                         2026.1.1  pyhcf101f3_0             conda-forge      11kB
#   + dask-core                                    2026.1.1  pyhcf101f3_1             conda-forge       1MB
#   + debugpy                                        1.8.20  py310h25320af_0          conda-forge       2MB
#   + decorator                                       5.2.1  pyhd8ed1ab_0             conda-forge      14kB
#   + defusedxml                                      0.7.1  pyhd8ed1ab_0             conda-forge      24kB
#   + distributed                                  2026.1.1  pyhcf101f3_1             conda-forge     844kB
#   + dnspython                                       2.8.0  pyhcf101f3_0             conda-forge     196kB
#   + email-validator                                 2.3.0  pyhd8ed1ab_0             conda-forge      47kB
#   + email_validator                                 2.3.0  hd8ed1ab_0               conda-forge       7kB
#   + exceptiongroup                                  1.3.1  pyhd8ed1ab_0             conda-forge      21kB
#   + executing                                       2.2.1  pyhd8ed1ab_0             conda-forge      31kB
#   + fastapi                                       0.125.0  h149372e_0               conda-forge       5kB
#   + fastapi-cli                                    0.0.20  pyhcf101f3_0             conda-forge      19kB
#   + fastapi-core                                  0.125.0  pyhcf101f3_0             conda-forge      89kB
#   + filelock                                       3.20.3  pyhd8ed1ab_0             conda-forge      19kB
#   + fonttools                                      4.61.1  py310h3406613_0          conda-forge       2MB
#   + fqdn                                            1.5.1  pyhd8ed1ab_1             conda-forge      17kB
#   + freetype                                       2.14.1  ha770c72_0               conda-forge     173kB
#   + frozendict                                      2.4.7  py310h7c4b9e2_0          conda-forge      50kB
#   + fsspec                                       2026.1.0  pyhd8ed1ab_0             conda-forge     148kB
#   + future                                          1.0.0  pyhd8ed1ab_2             conda-forge     365kB
#   + gflags                                          2.2.2  h5888daf_1005            conda-forge     120kB
#   + gitdb                                          4.0.12  pyhd8ed1ab_0             conda-forge      53kB
#   + gitpython                                      3.1.46  pyhd8ed1ab_0             conda-forge     158kB
#   + glog                                            0.7.1  hbabe93e_0               conda-forge     143kB
#   + h11                                            0.16.0  pyhcf101f3_1             conda-forge      39kB
#   + h2                                              4.3.0  pyhcf101f3_0             conda-forge      96kB
#   + h5py                                           3.15.1  nompi_py310h4aa865e_101  conda-forge       1MB
#   + hdf5                                           1.14.6  nompi_h1b119a7_105       conda-forge       4MB
#   + hpack                                           4.1.0  pyhd8ed1ab_0             conda-forge      31kB
#   + httpcore                                        1.0.9  pyh29332c3_0             conda-forge      49kB
#   + httptools                                       0.7.1  py310h7c4b9e2_1          conda-forge      98kB
#   + httpx                                          0.28.1  pyhd8ed1ab_0             conda-forge      63kB
#   + hyperframe                                      6.1.0  pyhd8ed1ab_0             conda-forge      17kB
#   + icu                                              78.2  h33c6efd_0               conda-forge      13MB
#   + idna                                             3.11  pyhd8ed1ab_0             conda-forge      51kB
#   + imagecodecs-lite                            2019.12.3  py310h261611a_8          conda-forge     170kB
#   + imageio                                        2.37.0  pyhfb79c49_0             conda-forge     293kB
#   + importlib-metadata                              8.7.0  pyhe01879c_1             conda-forge      35kB
#   + importlib_resources                             6.5.2  pyhd8ed1ab_0             conda-forge      34kB
#   + ipydatawidgets                                  4.3.2  pyhc268e32_0             conda-forge     172kB
#   + ipykernel                                       7.1.0  pyha191276_0             conda-forge     134kB
#   + ipyleaflet                                     0.20.0  pyhd8ed1ab_0             conda-forge      35kB
#   + ipympl                                         0.10.0  pyhcf101f3_0             conda-forge     244kB
#   + ipython                                        8.37.0  pyh8f84b5b_0             conda-forge     639kB
#   + ipython_genutils                                0.2.0  pyhd8ed1ab_2             conda-forge      28kB
#   + ipyvolume                                       0.6.3  pyhd8ed1ab_2             conda-forge       1MB
#   + ipyvue                                         1.11.2  pyhd8ed1ab_0             conda-forge       1MB
#   + ipyvuetify                                     1.11.3  pyhd8ed1ab_0             conda-forge       3MB
#   + ipywebrtc                                       0.6.0  pyhd8ed1ab_0             conda-forge     191kB
#   + ipywidgets                                      7.8.5  pyhd8ed1ab_0             conda-forge     105kB
#   + isoduration                                   20.11.0  pyhd8ed1ab_1             conda-forge      20kB
#   + jedi                                           0.19.2  pyhd8ed1ab_1             conda-forge     844kB
#   + jinja2                                          3.1.6  pyhcf101f3_1             conda-forge     121kB
#   + json5                                          0.13.0  pyhd8ed1ab_0             conda-forge      34kB
#   + jsonpointer                                     3.0.0  pyhcf101f3_3             conda-forge      14kB
#   + jsonschema                                     4.26.0  pyhcf101f3_0             conda-forge      82kB
#   + jsonschema-specifications                    2025.9.1  pyhcf101f3_0             conda-forge      19kB
#   + jsonschema-with-format-nongpl                  4.26.0  hcf101f3_0               conda-forge       5kB
#   + jupyter-lsp                                     2.3.0  pyhcf101f3_0             conda-forge      60kB
#   + jupyter_client                                  8.8.0  pyhcf101f3_0             conda-forge     113kB
#   + jupyter_core                                    5.9.1  pyhc90fa1f_0             conda-forge      66kB
#   + jupyter_events                                 0.12.0  pyh29332c3_0             conda-forge      24kB
#   + jupyter_leaflet                                0.20.0  pyhd8ed1ab_0             conda-forge     616kB
#   + jupyter_server                                 2.17.0  pyhcf101f3_0             conda-forge     347kB
#   + jupyter_server_terminals                        0.5.4  pyhcf101f3_0             conda-forge      22kB
#   + jupyterlab                                      4.5.3  pyhd8ed1ab_0             conda-forge       9MB
#   + jupyterlab_pygments                             0.3.0  pyhd8ed1ab_2             conda-forge      19kB
#   + jupyterlab_server                              2.28.0  pyhcf101f3_0             conda-forge      52kB
#   + jupyterlab_widgets                             1.1.11  pyhd8ed1ab_0             conda-forge     114kB
#   + keyutils                                        1.6.3  hb9d3cd8_0               conda-forge     134kB
#   + kiwisolver                                      1.4.9  py310haaf941d_2          conda-forge      78kB
#   + krb5                                           1.21.3  h659f571_0               conda-forge       1MB
#   + lark                                            1.3.1  pyhd8ed1ab_0             conda-forge      94kB
#   + lazy-loader                                       0.4  pyhd8ed1ab_2             conda-forge      16kB
#   + lazy_loader                                       0.4  pyhd8ed1ab_2             conda-forge       7kB
#   + lcms2                                            2.18  h0c24ade_0               conda-forge     250kB
#   + ld_impl_linux-64                                 2.45  default_hbd61a6d_105     conda-forge     731kB
#   + lerc                                            4.0.0  h0aef613_1               conda-forge     264kB
#   + libabseil                                  20250512.1  cxx17_hba17884_0         conda-forge       1MB
#   + libaec                                          1.1.5  h088129d_0               conda-forge      37kB
#   + libarrow                                       23.0.0  h2c50142_1_cpu           conda-forge       6MB
#   + libarrow-acero                                 23.0.0  h635bf11_1_cpu           conda-forge     610kB
#   + libarrow-compute                               23.0.0  h8c2c5c3_1_cpu           conda-forge       3MB
#   + libarrow-dataset                               23.0.0  h635bf11_1_cpu           conda-forge     609kB
#   + libarrow-substrait                             23.0.0  h3f74fd7_1_cpu           conda-forge     517kB
#   + libblas                                        3.11.0  5_h4a7cf45_openblas      conda-forge      18kB
#   + libbrotlicommon                                 1.2.0  hb03c661_1               conda-forge      80kB
#   + libbrotlidec                                    1.2.0  hb03c661_1               conda-forge      35kB
#   + libbrotlienc                                    1.2.0  hb03c661_1               conda-forge     298kB
#   + libcblas                                       3.11.0  5_h0358290_openblas      conda-forge      18kB
#   + libcrc32c                                       1.1.2  h9c3ff4c_0               conda-forge      20kB
#   + libcurl                                        8.18.0  h4e3cde8_0               conda-forge     463kB
#   + libdeflate                                       1.25  h17f619e_0               conda-forge      73kB
#   + libedit                                  3.1.20250104  pl5321h7949ede_0         conda-forge     135kB
#   + libev                                            4.33  hd590300_2               conda-forge     113kB
#   + libevent                                       2.1.12  hf998b51_1               conda-forge     427kB
#   + libexpat                                        2.7.3  hecca717_0               conda-forge      77kB
#   + libffi                                          3.5.2  h3435931_0               conda-forge      59kB
#   + libfreetype                                    2.14.1  ha770c72_0               conda-forge       8kB
#   + libfreetype6                                   2.14.1  h73754d4_0               conda-forge     387kB
#   + libgcc                                         15.2.0  he0feb66_16              conda-forge       1MB
#   + libgcc-ng                                      15.2.0  h69a702a_16              conda-forge      27kB
#   + libgfortran                                    15.2.0  h69a702a_16              conda-forge      27kB
#   + libgfortran5                                   15.2.0  h68bc16d_16              conda-forge       2MB
#   + libgomp                                        15.2.0  he0feb66_16              conda-forge     603kB
#   + libgoogle-cloud                                2.39.0  hdb79228_0               conda-forge       1MB
#   + libgoogle-cloud-storage                        2.39.0  hdbdcf42_0               conda-forge     804kB
#   + libgrpc                                        1.73.1  h3288cfb_1               conda-forge       8MB
#   + libiconv                                         1.18  h3b78370_2               conda-forge     790kB
#   + libjpeg-turbo                                   3.1.2  hb03c661_0               conda-forge     634kB
#   + liblapack                                      3.11.0  5_h47877c9_openblas      conda-forge      18kB
#   + liblzma                                         5.8.2  hb03c661_0               conda-forge     113kB
#   + libnghttp2                                     1.67.0  had1ee68_0               conda-forge     667kB
#   + libnsl                                          2.0.1  hb9d3cd8_1               conda-forge      34kB
#   + libopenblas                                    0.3.30  pthreads_h94d23a6_4      conda-forge       6MB
#   + libopentelemetry-cpp                           1.21.0  hb9b0907_1               conda-forge     885kB
#   + libopentelemetry-cpp-headers                   1.21.0  ha770c72_1               conda-forge     363kB
#   + libparquet                                     23.0.0  h7376487_1_cpu           conda-forge       1MB
#   + libpng                                         1.6.54  h421ea60_0               conda-forge     317kB
#   + libprotobuf                                    6.31.1  h49aed37_4               conda-forge       4MB
#   + libre2-11                                  2025.11.05  h7b12aa8_0               conda-forge     211kB
#   + libsodium                                      1.0.20  h4ab18f5_0               conda-forge     206kB
#   + libsqlite                                      3.51.2  hf4e2dac_0               conda-forge     943kB
#   + libssh2                                        1.11.1  hcf80075_0               conda-forge     305kB
#   + libstdcxx                                      15.2.0  h934c35e_16              conda-forge       6MB
#   + libstdcxx-ng                                   15.2.0  hdf11a46_16              conda-forge      27kB
#   + libthrift                                      0.22.0  h454ac66_1               conda-forge     424kB
#   + libtiff                                         4.7.1  h9d88235_1               conda-forge     435kB
#   + libutf8proc                                    2.11.3  hfe17d71_0               conda-forge      86kB
#   + libuuid                                        2.41.3  h5347b49_0               conda-forge      40kB
#   + libuv                                          1.51.0  hb03c661_1               conda-forge     895kB
#   + libwebp-base                                    1.6.0  hd42ef1d_0               conda-forge     429kB
#   + libxcb                                         1.17.0  h8a09558_0               conda-forge     396kB
#   + libxcrypt                                      4.4.36  hd590300_1               conda-forge     100kB
#   + libxml2                                        2.15.1  he237659_1               conda-forge      45kB
#   + libxml2-16                                     2.15.1  hca6bf5a_1               conda-forge     556kB
#   + libzlib                                         1.3.1  hb9d3cd8_2               conda-forge      61kB
#   + llvmlite                                       0.46.0  py310hee1c697_0          conda-forge      34MB
#   + locket                                          1.0.0  pyhd8ed1ab_0             conda-forge       8kB
#   + lz4                                             4.4.5  py310hde1b0b5_1          conda-forge      42kB
#   + lz4-c                                          1.10.0  h5888daf_1               conda-forge     167kB
#   + markdown-it-py                                  4.0.0  pyhd8ed1ab_0             conda-forge      65kB
#   + markupsafe                                      3.0.3  py310h3406613_0          conda-forge      24kB
#   + matplotlib-base                                3.10.8  py310hfde16b3_0          conda-forge       7MB
#   + matplotlib-inline                               0.2.1  pyhd8ed1ab_0             conda-forge      15kB
#   + mdurl                                           0.1.2  pyhd8ed1ab_1             conda-forge      14kB
#   + mistune                                         3.2.0  pyhcf101f3_0             conda-forge      74kB
#   + msgpack-python                                  1.1.2  py310h03d9f68_1          conda-forge      95kB
#   + munkres                                         1.1.4  pyhd8ed1ab_1             conda-forge      16kB
#   + narwhals                                       2.15.0  pyhcf101f3_0             conda-forge     272kB
#   + nbclient                                       0.10.4  pyhd8ed1ab_0             conda-forge      28kB
#   + nbconvert-core                                 7.17.0  pyhcf101f3_0             conda-forge     202kB
#   + nbformat                                       5.10.4  pyhd8ed1ab_1             conda-forge     101kB
#   + ncurses                                           6.5  h2d0b736_3               conda-forge     892kB
#   + nest-asyncio                                    1.6.0  pyhd8ed1ab_1             conda-forge      12kB
#   + networkx                                        3.4.2  pyh267e887_2             conda-forge       1MB
#   + nlohmann_json                                  3.12.0  h54a6638_1               conda-forge     136kB
#   + notebook                                        7.5.3  pyhcf101f3_0             conda-forge      10MB
#   + notebook-shim                                   0.2.4  pyhd8ed1ab_1             conda-forge      17kB
#   + numba                                          0.63.1  py310h225f558_0          conda-forge       4MB
#   + numpy                                          1.26.4  py310hb13e2d6_0          conda-forge       7MB
#   + openjpeg                                        2.5.4  h55fea9a_0               conda-forge     355kB
#   + openssl                                         3.6.1  h35e630c_1               conda-forge       3MB
#   + orc                                             2.2.2  h19cb568_0               conda-forge       1MB
#   + overrides                                       7.7.0  pyhd8ed1ab_1             conda-forge      30kB
#   + packaging                                        26.0  pyhcf101f3_0             conda-forge      72kB
#   + pandas                                          2.3.3  py310h0158d43_2          conda-forge      12MB
#   + pandocfilters                                   1.5.0  pyhd8ed1ab_0             conda-forge      12kB
#   + parso                                           0.8.5  pyhcf101f3_0             conda-forge      82kB
#   + partd                                           1.4.2  pyhd8ed1ab_0             conda-forge      21kB
#   + pcre                                             8.45  h9c3ff4c_0               conda-forge     259kB
#   + pexpect                                         4.9.0  pyhd8ed1ab_1             conda-forge      54kB
#   + pickleshare                                     0.7.5  pyhd8ed1ab_1004          conda-forge      12kB
#   + pillow                                         12.1.0  py310h5a73078_0          conda-forge     883kB
#   + pip                                              26.0  pyh8b19718_0             conda-forge       1MB
#   + platformdirs                                    4.5.1  pyhcf101f3_0             conda-forge      24kB
#   + plotly                                          6.5.2  pyhd8ed1ab_0             conda-forge       5MB
#   + progressbar2                                    4.5.0  pyhd8ed1ab_1             conda-forge      55kB
#   + prometheus-cpp                                  1.3.0  ha5d0236_0               conda-forge     200kB
#   + prometheus_client                              0.24.1  pyhd8ed1ab_0             conda-forge      57kB
#   + prompt-toolkit                                 3.0.52  pyha770c72_0             conda-forge     274kB
#   + protobuf                                       6.31.1  py310ha36e12e_2          conda-forge     405kB
#   + psutil                                          7.2.2  py310h139afa4_0          conda-forge     179kB
#   + pthread-stubs                                     0.4  hb9d3cd8_1002            conda-forge       8kB
#   + ptyprocess                                      0.7.0  pyhd8ed1ab_1             conda-forge      19kB
#   + pure_eval                                       0.2.3  pyhd8ed1ab_1             conda-forge      17kB
#   + pyarrow                                        23.0.0  py310hff52083_0          conda-forge      27kB
#   + pyarrow-core                                   23.0.0  py310h923f568_0_cpu      conda-forge       5MB
#   + pycparser                                        2.22  pyh29332c3_1             conda-forge     110kB
#   + pydantic                                      1.10.22  pyh3cfb1c2_0             conda-forge     138kB
#   + pydeck                                          0.9.1  pyhd8ed1ab_0             conda-forge       5MB
#   + pyerfa                                        2.0.1.5  py310h32771cd_2          conda-forge     296kB
#   + pygments                                       2.19.2  pyhd8ed1ab_0             conda-forge     889kB
#   + pyparsing                                       3.3.2  pyhcf101f3_0             conda-forge     111kB
#   + pysocks                                         1.7.1  pyha55dd90_7             conda-forge      21kB
#   + python                                        3.10.19  h3c07f61_3_cpython       conda-forge      25MB
#   + python-dateutil                           2.9.0.post0  pyhe01879c_2             conda-forge     233kB
#   + python-dotenv                                   1.2.1  pyhcf101f3_0             conda-forge      27kB
#   + python-fastjsonschema                          2.21.2  pyhe01879c_0             conda-forge     245kB
#   + python-json-logger                              2.0.7  pyhd8ed1ab_0             conda-forge      13kB
#   + python-multipart                               0.0.22  pyhcf101f3_0             conda-forge      30kB
#   + python-tzdata                                  2025.3  pyhd8ed1ab_0             conda-forge     144kB
#   + python-utils                                    3.9.1  pyhff2d567_1             conda-forge      32kB
#   + python_abi                                       3.10  8_cp310                  conda-forge       7kB
#   + pythreejs                                       2.4.2  pyhbbac1ac_1             conda-forge       1MB
#   + pytz                                           2025.2  pyhd8ed1ab_0             conda-forge     189kB
#   + pywavelets                                      1.8.0  py310hf462985_0          conda-forge       4MB
#   + pyyaml                                          6.0.3  py310h3406613_0          conda-forge     181kB
#   + pyzmq                                          27.1.0  py310h4f33d48_0          conda-forge     327kB
#   + qhull                                          2020.2  h434a139_5               conda-forge     553kB
#   + re2                                        2025.11.05  h5301d42_0               conda-forge      27kB
#   + readline                                          8.3  h853b02a_0               conda-forge     345kB
#   + referencing                                    0.37.0  pyhcf101f3_0             conda-forge      52kB
#   + requests                                       2.32.5  pyhcf101f3_1             conda-forge      64kB
#   + rfc3339-validator                               0.1.4  pyhd8ed1ab_1             conda-forge      10kB
#   + rfc3986-validator                               0.1.1  pyh9f0ad1d_0             conda-forge       8kB
#   + rfc3987-syntax                                  1.1.0  pyhe01879c_1             conda-forge      23kB
#   + rich                                           14.3.1  pyhcf101f3_0             conda-forge     208kB
#   + rich-toolkit                                   0.17.2  pyhcf101f3_0             conda-forge      31kB
#   + rpds-py                                        0.30.0  py310hd8f68c5_0          conda-forge     383kB
#   + s2n                                             1.6.2  he8a4886_1               conda-forge     394kB
#   + scikit-image                                   0.20.0  py310h9b08913_1          conda-forge      10MB
#   + scipy                                          1.15.2  py310h1d65ade_0          conda-forge      16MB
#   + send2trash                                      2.1.0  pyha191276_0             conda-forge      24kB
#   + setuptools                                    80.10.2  pyh332efcf_0             conda-forge     679kB
#   + shellingham                                     1.5.4  pyhd8ed1ab_2             conda-forge      15kB
#   + six                                            1.17.0  pyhe01879c_1             conda-forge      18kB
#   + smmap                                           5.0.2  pyhd8ed1ab_0             conda-forge      26kB
#   + snappy                                          1.2.2  h03e3b7b_1               conda-forge      46kB
#   + sniffio                                         1.3.1  pyhd8ed1ab_2             conda-forge      16kB
#   + sortedcontainers                                2.4.0  pyhd8ed1ab_1             conda-forge      29kB
#   + soupsieve                                       2.8.3  pyhd8ed1ab_0             conda-forge      38kB
#   + stack_data                                      0.6.3  pyhd8ed1ab_1             conda-forge      27kB
#   + starlette                                      0.50.0  pyhfdc7a7d_0             conda-forge      65kB
#   + streamlit                                      1.53.1  pyhd8ed1ab_0             conda-forge       8MB
#   + tabulate                                        0.9.0  pyhcf101f3_3             conda-forge      40kB
#   + tblib                                           3.2.2  pyhcf101f3_0             conda-forge      19kB
#   + tenacity                                        9.1.2  pyhd8ed1ab_0             conda-forge      25kB
#   + terminado                                      0.18.1  pyhc90fa1f_1             conda-forge      25kB
#   + tifffile                                     2020.6.3  py_0                     conda-forge     111kB
#   + tinycss2                                        1.5.1  pyhcf101f3_0             conda-forge      31kB
#   + tk                                             8.6.13  noxft_h366c992_103       conda-forge       3MB
#   + toml                                           0.10.2  pyhcf101f3_3             conda-forge      24kB
#   + tomli                                           2.4.0  pyhcf101f3_0             conda-forge      21kB
#   + toolz                                           1.1.0  pyhd8ed1ab_1             conda-forge      54kB
#   + tornado                                         6.5.4  py310ha78b2d2_0          conda-forge     662kB
#   + traitlets                                      5.14.3  pyhd8ed1ab_1             conda-forge     110kB
#   + traittypes                                      0.2.3  pyh332efcf_0             conda-forge      13kB
#   + typer                                          0.21.1  pyhf8876ea_0             conda-forge      82kB
#   + typer-slim                                     0.21.1  pyhcf101f3_0             conda-forge      48kB
#   + typer-slim-standard                            0.21.1  h378290b_0               conda-forge       5kB
#   + typing-extensions                              4.15.0  h396c80c_0               conda-forge      91kB
#   + typing_extensions                              4.15.0  pyhcf101f3_0             conda-forge      52kB
#   + typing_utils                                    0.1.0  pyhd8ed1ab_1             conda-forge      15kB
#   + tzdata                                          2025c  hc9c84f9_1               conda-forge     119kB
#   + unicodedata2                                   17.0.0  py310h7c4b9e2_1          conda-forge     410kB
#   + uri-template                                    1.3.0  pyhd8ed1ab_1             conda-forge      24kB
#   + urllib3                                         2.6.3  pyhd8ed1ab_0             conda-forge     103kB
#   + uvicorn                                        0.40.0  pyhc90fa1f_0             conda-forge      55kB
#   + uvicorn-standard                               0.40.0  h4cd5af1_0               conda-forge       4kB
#   + uvloop                                         0.22.1  py310h7c4b9e2_1          conda-forge     576kB
#   + vaex                                           4.16.0  pyhd8ed1ab_0             conda-forge      10kB
#   + vaex-astro                                      0.9.3  pyhd8ed1ab_0             conda-forge      22kB
#   + vaex-core                                      4.16.1  py310hc57749c_0          conda-forge      45MB
#   + vaex-hdf5                                      0.14.1  pyhd8ed1ab_0             conda-forge      19kB
#   + vaex-jupyter                                    0.8.1  pyhd8ed1ab_0             conda-forge      40kB
#   + vaex-ml                                        0.18.1  pyhd8ed1ab_0             conda-forge      44kB
#   + vaex-server                                     0.8.1  pyhd8ed1ab_0             conda-forge      23kB
#   + vaex-viz                                        0.5.4  pyhd8ed1ab_0             conda-forge      21kB
#   + watchdog                                        6.0.0  py310hff52083_2          conda-forge     116kB
#   + watchfiles                                      1.1.1  py310hdfeec95_0          conda-forge     414kB
#   + wcwidth                                         0.5.3  pyhd8ed1ab_0             conda-forge      71kB
#   + webcolors                                     25.10.0  pyhd8ed1ab_0             conda-forge      19kB
#   + webencodings                                    0.5.1  pyhd8ed1ab_3             conda-forge      15kB
#   + websocket-client                                1.9.0  pyhd8ed1ab_0             conda-forge      61kB
#   + websockets                                       16.0  py310h139afa4_1          conda-forge     296kB
#   + wheel                                          0.46.3  pyhd8ed1ab_0             conda-forge      32kB
#   + widgetsnbextension                             3.6.10  pyhd8ed1ab_0             conda-forge     634kB
#   + xarray                                       2025.6.1  pyhd8ed1ab_1             conda-forge     880kB
#   + xorg-libxau                                    1.0.12  hb03c661_1               conda-forge      15kB
#   + xorg-libxdmcp                                   1.1.5  hb03c661_1               conda-forge      21kB
#   + xyzservices                                 2025.11.0  pyhd8ed1ab_0             conda-forge      51kB
#   + yaml                                            0.2.5  h280c20c_3               conda-forge      85kB
#   + zeromq                                          4.3.5  h387f397_9               conda-forge     311kB
#   + zict                                            3.0.0  pyhd8ed1ab_1             conda-forge      36kB
#   + zipp                                           3.23.0  pyhcf101f3_1             conda-forge      24kB
#   + zlib                                            1.3.1  hb9d3cd8_2               conda-forge      92kB
#   + zlib-ng                                         2.3.2  hceb46e0_1               conda-forge     122kB
#   + zstd                                            1.5.7  hb78ec9c_6               conda-forge     601kB
#
#   Summary:
#
#   Install: 350 packages
#
#   Total download: 366MB
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading        5%
# Extracting         0%[+] 0.1s
# Downloading  (5)   2%
# Extracting         0%[+] 0.2s
# Downloading  (5)  21%
# Extracting         0%icu                                                 12.7MB @  38.0MB/s  0.2s
# [+] 0.3s
# Downloading  (5)  34%
# Extracting         0%python                                              25.4MB @  71.6MB/s  0.3s
# [+] 0.4s
# Downloading  (5)  39%
# Extracting   (1)  ⣾  scipy                                               16.4MB @  33.4MB/s  0.4s
# [+] 0.5s
# Downloading  (5)  52%
# Extracting   (1)  ⣾  [+] 0.6s
# Downloading  (5)  60%
# Extracting   (2)  ⣾  [+] 0.7s
# Downloading  (5)  67%
# Extracting   (2)  ⣾  [+] 0.8s
# Downloading  (5)  73%
# Extracting   (3)  ⣾  [+] 0.9s
# Downloading  (5)  77%
# Extracting   (3)  ⣾  notebook                                            10.0MB @  20.5MB/s  0.5s
# scikit-image                                        10.4MB @  14.8MB/s  0.6s
# pandas                                              12.4MB @  17.2MB/s  0.7s
# [+] 1.0s
# Downloading  (4)  80%
# Extracting   (3)  ⣾  [+] 1.1s
# Downloading  (5)  83%
# Extracting   (3)  ⣾  [+] 1.2s
# Downloading  (5)  87%
# Extracting   (5)  ⣾  llvmlite                                            34.0MB @  27.3MB/s  1.2s
# libgrpc                                              8.3MB @  28.6MB/s  0.3s
# jupyterlab                                           8.6MB @  26.3MB/s  0.3s
# [+] 1.3s
# Downloading  (5)  87%
# Extracting   (6)  ⣾  vaex-core                                           45.3MB @  33.7MB/s  1.3s
# astropy                                              7.7MB @  20.2MB/s  0.4s
# [+] 1.4s
# Downloading  (5)  86%
# Extracting   (6)  ⣾  [+] 1.5s
# Downloading  (5)  87%
# Extracting   (6)  ⣾  [+] 1.6s
# Downloading  (5)  89%
# Extracting   (6)  ⣾  [+] 1.7s
# Downloading  (5)  92%
# Extracting   (7)  ⣾  matplotlib-base                                      7.3MB @  14.5MB/s  0.5s
# [+] 1.8s
# Downloading  (5)  94%
# Extracting   (8)  ⣾  numpy                                                7.0MB @  13.5MB/s  0.5s
# libarrow                                             6.5MB @  12.5MB/s  0.5s
# babel                                                6.9MB @  12.8MB/s  0.5s
# [+] 1.9s
# Downloading  (5)  92%
# Extracting   (8)  ⣾  streamlit                                            7.5MB @  11.1MB/s  0.7s
# [+] 2.0s
# Downloading  (5)  92%
# Extracting   (8)  ⣾  [+] 2.1s
# Downloading  (5)  94%
# Extracting  (10)  ⣾  libopenblas                                          5.9MB @  13.2MB/s  0.4s
# plotly                                               4.9MB @  11.5MB/s  0.3s
# pyarrow-core                                         5.3MB @  15.0MB/s  0.3s
# libstdcxx                                            5.9MB @  14.8MB/s  0.4s
# [+] 2.2s
# Downloading  (5)  93%
# Extracting  (12)  ⣾  pydeck                                               4.8MB @  19.1MB/s  0.2s
# [+] 2.3s
# Downloading  (5)  94%
# Extracting  (13)  ⣾  [+] 2.4s
# Downloading  (5)  96%
# Extracting  (15)  ⣾  bokeh                                                4.7MB @  16.4MB/s  0.3s
# [+] 2.5s
# Downloading  (5)  97%
# Extracting  (19)  ⣾  libprotobuf                                          4.4MB @  11.9MB/s  0.3s
# numba                                                4.4MB @  12.2MB/s  0.4s
# hdf5                                                 3.7MB @   9.4MB/s  0.3s
# pywavelets                                           3.7MB @  11.3MB/s  0.3s
# [+] 2.6s
# Downloading  (5)  96%
# Extracting  (19)  ⣾  aws-sdk-cpp                                          3.5MB @  25.3MB/s  0.2s
# [+] 2.7s
# Downloading  (5)  97%
# Extracting  (20)  ⣾  [+] 2.8s
# Downloading  (5)  97%
# Extracting  (24)  ⣾  libarrow-compute                                     3.0MB @   8.6MB/s  0.3s
# tk                                                   3.3MB @  10.3MB/s  0.3s
# ...
# Downloading      100%
# Extracting  (78)  ⣾  [+] 28.9s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 29.0s
# Downloading      100%
# Extracting  (76)  ⣾  [+] 29.1s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 29.2s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 29.3s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 29.4s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 29.5s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 29.6s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 29.7s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 29.8s
# Downloading      100%
# Extracting  (65)  ⣾  [+] 29.9s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 30.0s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 30.1s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 30.2s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 30.3s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 30.4s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 30.5s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 30.6s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 30.7s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 30.8s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 30.9s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 31.0s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 31.1s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 31.2s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 31.3s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 31.4s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 31.5s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 31.6s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 31.7s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 31.8s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 31.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 32.0s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 32.1s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 32.2s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 32.3s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 32.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 32.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 32.6s
# Downloading      100%
# Extracting   (2)  ⣾  Linking python_abi-3.10-8_cp310
# Linking tzdata-2025c-hc9c84f9_1
# Linking ca-certificates-2026.1.4-hbd8a1cb_0
# Linking libopentelemetry-cpp-headers-1.21.0-ha770c72_1
# Linking nlohmann_json-3.12.0-h54a6638_1
# Linking libgomp-15.2.0-he0feb66_16
# Linking _libgcc_mutex-0.1-conda_forge
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-15.2.0-he0feb66_16
# Linking libiconv-1.18-h3b78370_2
# Linking libffi-3.5.2-h3435931_0
# Linking libuv-1.51.0-hb03c661_1
# Linking libgfortran5-15.2.0-h68bc16d_16
# Linking keyutils-1.6.3-hb9d3cd8_0
# Linking libbrotlicommon-1.2.0-hb03c661_1
# Linking c-ares-1.34.6-hb03c661_0
# Linking xorg-libxdmcp-1.1.5-hb03c661_1
# Linking xorg-libxau-1.0.12-hb03c661_1
# Linking pthread-stubs-0.4-hb9d3cd8_1002
# Linking libdeflate-1.25-h17f619e_0
# Linking libwebp-base-1.6.0-hd42ef1d_0
# Linking libjpeg-turbo-3.1.2-hb03c661_0
# Linking libutf8proc-2.11.3-hfe17d71_0
# Linking aws-c-common-0.12.6-hb03c661_0
# Linking openssl-3.6.1-h35e630c_1
# Linking libzlib-1.3.1-hb9d3cd8_2
# Linking libnsl-2.0.1-hb9d3cd8_1
# Linking bzip2-1.0.8-hda65f42_8
# Linking yaml-0.2.5-h280c20c_3
# Linking ncurses-6.5-h2d0b736_3
# Linking libstdcxx-15.2.0-h934c35e_16
# Linking libgcc-ng-15.2.0-h69a702a_16
# Linking libuuid-2.41.3-h5347b49_0
# Linking liblzma-5.8.2-hb03c661_0
# Linking libexpat-2.7.3-hecca717_0
# Linking libgfortran-15.2.0-h69a702a_16
# Linking libbrotlienc-1.2.0-hb03c661_1
# Linking libbrotlidec-1.2.0-hb03c661_1
# Linking libxcb-1.17.0-h8a09558_0
# Linking aws-c-compression-0.3.1-h8b1a151_9
# Linking aws-checksums-0.2.7-h8b1a151_5
# Linking aws-c-sdkutils-0.2.4-h8b1a151_4
# Linking s2n-1.6.2-he8a4886_1
# Linking aws-c-cal-0.9.13-h2c9d079_1
# Linking libssh2-1.11.1-hcf80075_0
# Linking tk-8.6.13-noxft_h366c992_103
# Linking libpng-1.6.54-h421ea60_0
# Linking zstd-1.5.7-hb78ec9c_6
# Linking zlib-1.3.1-hb9d3cd8_2
# Linking libedit-3.1.20250104-pl5321h7949ede_0
# Linking readline-8.3-h853b02a_0
# Linking icu-78.2-h33c6efd_0
# Linking libaec-1.1.5-h088129d_0
# Linking gflags-2.2.2-h5888daf_1005
# Linking lerc-4.0.0-h0aef613_1
# Linking snappy-1.2.2-h03e3b7b_1
# Linking lz4-c-1.10.0-h5888daf_1
# Linking zlib-ng-2.3.2-hceb46e0_1
# Linking libabseil-20250512.1-cxx17_hba17884_0
# Linking libstdcxx-ng-15.2.0-hdf11a46_16
# Linking libsodium-1.0.20-h4ab18f5_0
# Linking libevent-2.1.12-hf998b51_1
# Linking libev-4.33-hd590300_2
# Linking libxcrypt-4.4.36-hd590300_1
# Linking libopenblas-0.3.30-pthreads_h94d23a6_4
# Linking brotli-bin-1.2.0-hb03c661_1
# Linking aws-c-io-0.23.3-hdaf4b65_5
# Linking libfreetype6-2.14.1-h73754d4_0
# Linking ld_impl_linux-64-2.45-default_hbd61a6d_105
# Linking libxml2-16-2.15.1-hca6bf5a_1
# Linking libsqlite-3.51.2-hf4e2dac_0
# Linking libtiff-4.7.1-h9d88235_1
# Linking libre2-11-2025.11.05-h7b12aa8_0
# Linking libprotobuf-6.31.1-h49aed37_4
# Linking qhull-2020.2-h434a139_5
# Linking krb5-1.21.3-h659f571_0
# Linking libcrc32c-1.1.2-h9c3ff4c_0
# Linking glog-0.7.1-hbabe93e_0
# Linking pcre-8.45-h9c3ff4c_0
# Linking libthrift-0.22.0-h454ac66_1
# Linking libnghttp2-1.67.0-had1ee68_0
# Linking libblas-3.11.0-5_h4a7cf45_openblas
# Linking brotli-1.2.0-hed03a55_1
# Linking aws-c-http-0.10.7-ha8fc4e3_5
# Linking aws-c-event-stream-0.5.7-h28f887f_1
# Linking libfreetype-2.14.1-ha770c72_0
# Linking libxml2-2.15.1-he237659_1
# Linking python-3.10.19-h3c07f61_3_cpython
# Linking lcms2-2.18-h0c24ade_0
# Linking openjpeg-2.5.4-h55fea9a_0
# Linking re2-2025.11.05-h5301d42_0
# Linking orc-2.2.2-h19cb568_0
# Linking zeromq-4.3.5-h387f397_9
# Linking libcurl-8.18.0-h4e3cde8_0
# Linking libcblas-3.11.0-5_h0358290_openblas
# Linking liblapack-3.11.0-5_h47877c9_openblas
# Linking aws-c-mqtt-0.13.3-hc63082f_11
# Linking aws-c-auth-0.9.3-hef928c7_0
# Linking freetype-2.14.1-ha770c72_0
# Linking libgrpc-1.73.1-h3288cfb_1
# Linking hdf5-1.14.6-nompi_h1b119a7_105
# Linking prometheus-cpp-1.3.0-ha5d0236_0
# Linking azure-core-cpp-1.16.1-h3a458e0_0
# Linking aws-c-s3-0.11.3-h06ab39a_1
# Linking libgoogle-cloud-2.39.0-hdb79228_0
# Linking libopentelemetry-cpp-1.21.0-hb9b0907_1
# Linking azure-identity-cpp-1.13.2-h3a5f585_1
# Linking azure-storage-common-cpp-12.12.0-h3d7a050_0
# Linking aws-crt-cpp-0.35.4-h8824e59_0
# Linking libgoogle-cloud-storage-2.39.0-hdbdcf42_0
# Linking azure-storage-blobs-cpp-12.16.0-h75daedc_0
# Linking aws-sdk-cpp-1.11.606-h20b40b1_10
# Linking azure-storage-files-datalake-cpp-12.14.0-hd454692_0
# Linking libarrow-23.0.0-h2c50142_1_cpu
# Linking libarrow-compute-23.0.0-h8c2c5c3_1_cpu
# Linking libparquet-23.0.0-h7376487_1_cpu
# Linking libarrow-acero-23.0.0-h635bf11_1_cpu
# Linking libarrow-dataset-23.0.0-h635bf11_1_cpu
# Linking libarrow-substrait-23.0.0-h3f74fd7_1_cpu
# Linking setuptools-80.10.2-pyh332efcf_0
# Linking packaging-26.0-pyhcf101f3_0
# Linking wheel-0.46.3-pyhd8ed1ab_0
# Linking pip-26.0-pyh8b19718_0
# Linking pycparser-2.22-pyh29332c3_1
# Linking soupsieve-2.8.3-pyhd8ed1ab_0
# Linking webencodings-0.5.1-pyhd8ed1ab_3
# Linking parso-0.8.5-pyhcf101f3_0
# Linking pandocfilters-1.5.0-pyhd8ed1ab_0
# Linking defusedxml-0.7.1-pyhd8ed1ab_0
# Linking python-fastjsonschema-2.21.2-pyhe01879c_0
# Linking typing_utils-0.1.0-pyhd8ed1ab_1
# Linking wcwidth-0.5.3-pyhd8ed1ab_0
# Linking lark-1.3.1-pyhd8ed1ab_0
# Linking pure_eval-0.2.3-pyhd8ed1ab_1
# Linking executing-2.2.1-pyhd8ed1ab_0
# Linking asttokens-3.0.1-pyhd8ed1ab_0
# Linking ptyprocess-0.7.0-pyhd8ed1ab_1
# Linking shellingham-1.5.4-pyhd8ed1ab_2
# Linking cached_property-1.5.2-pyha770c72_1
# Linking pickleshare-0.7.5-pyhd8ed1ab_1004
# Linking decorator-5.2.1-pyhd8ed1ab_0
# Linking jupyterlab_widgets-1.1.11-pyhd8ed1ab_0
# Linking comm-0.2.3-pyhe01879c_0
# Linking webcolors-25.10.0-pyhd8ed1ab_0
# Linking uri-template-1.3.0-pyhd8ed1ab_1
# Linking jsonpointer-3.0.0-pyhcf101f3_3
# Linking platformdirs-4.5.1-pyhcf101f3_0
# Linking python-json-logger-2.0.7-pyhd8ed1ab_0
# Linking websocket-client-1.9.0-pyhd8ed1ab_0
# Linking send2trash-2.1.0-pyha191276_0
# Linking prometheus_client-0.24.1-pyhd8ed1ab_0
# Linking rfc3986-validator-0.1.1-pyh9f0ad1d_0
# Linking tomli-2.4.0-pyhcf101f3_0
# Linking json5-0.13.0-pyhd8ed1ab_0
# Linking python-dotenv-1.2.1-pyhcf101f3_0
# Linking astropy-iers-data-0.2026.1.26.0.43.56-pyhd8ed1ab_0
# Linking munkres-1.1.4-pyhd8ed1ab_1
# Linking pyparsing-3.3.2-pyhcf101f3_0
# Linking cycler-0.12.1-pyhcf101f3_2
# Linking networkx-3.4.2-pyh267e887_2
# Linking sniffio-1.3.1-pyhd8ed1ab_2
# Linking python-multipart-0.0.22-pyhcf101f3_0
# Linking annotated-doc-0.0.4-pyhcf101f3_0
# Linking zipp-3.23.0-pyhcf101f3_1
# Linking ipython_genutils-0.2.0-pyhd8ed1ab_2
# Linking attrs-25.4.0-pyhcf101f3_1
# Linking pysocks-1.7.1-pyha55dd90_7
# Linking hyperframe-6.1.0-pyhd8ed1ab_0
# Linking hpack-4.1.0-pyhd8ed1ab_0
# Linking jupyter_leaflet-0.20.0-pyhd8ed1ab_0
# Linking traitlets-5.14.3-pyhd8ed1ab_1
# Linking pytz-2025.2-pyhd8ed1ab_0
# Linking python-tzdata-2025.3-pyhd8ed1ab_0
# Linking xyzservices-2025.11.0-pyhd8ed1ab_0
# Linking fsspec-2026.1.0-pyhd8ed1ab_0
# Linking zict-3.0.0-pyhd8ed1ab_1
# Linking toolz-1.1.0-pyhd8ed1ab_1
# Linking tblib-3.2.2-pyhcf101f3_0
# Linking sortedcontainers-2.4.0-pyhd8ed1ab_1
# Linking smmap-5.0.2-pyhd8ed1ab_0
# Linking mdurl-0.1.2-pyhd8ed1ab_1
# Linking charset-normalizer-3.4.4-pyhd8ed1ab_0
# Linking idna-3.11-pyhd8ed1ab_0
# Linking certifi-2026.1.4-pyhd8ed1ab_0
# Linking pygments-2.19.2-pyhd8ed1ab_0
# Linking toml-0.10.2-pyhcf101f3_3
# Linking tenacity-9.1.2-pyhd8ed1ab_0
# Linking cachetools-6.2.6-pyhd8ed1ab_0
# Linking blinker-1.9.0-pyhff2d567_0
# Linking click-8.3.1-pyh8f84b5b_1
# Linking tabulate-0.9.0-pyhcf101f3_3
# Linking nest-asyncio-1.6.0-pyhd8ed1ab_1
# Linking six-1.17.0-pyhe01879c_1
# Linking future-1.0.0-pyhd8ed1ab_2
# Linking filelock-3.20.3-pyhd8ed1ab_0
# Linking locket-1.0.0-pyhd8ed1ab_0
# Linking cloudpickle-3.1.2-pyhcf101f3_1
# Linking narwhals-2.15.0-pyhcf101f3_0
# Linking typing_extensions-4.15.0-pyhcf101f3_0
# Linking aplus-0.11.0-py_1
# Linking tinycss2-1.5.1-pyhcf101f3_0
# Linking bleach-6.3.0-pyhcf101f3_0
# Linking jedi-0.19.2-pyhd8ed1ab_1
# Linking overrides-7.7.0-pyhd8ed1ab_1
# Linking prompt-toolkit-3.0.52-pyha770c72_0
# Linking rfc3987-syntax-1.1.0-pyhe01879c_1
# Linking stack_data-0.6.3-pyhd8ed1ab_1
# Linking pexpect-4.9.0-pyhd8ed1ab_1
# Linking cached-property-1.5.2-hd8ed1ab_1
# Linking dnspython-2.8.0-pyhcf101f3_0
# Linking importlib_resources-6.5.2-pyhd8ed1ab_0
# Linking importlib-metadata-8.7.0-pyhe01879c_1
# Linking h2-4.3.0-pyhcf101f3_0
# Linking matplotlib-inline-0.2.1-pyhd8ed1ab_0
# Linking jupyter_core-5.9.1-pyhc90fa1f_0
# Linking traittypes-0.2.3-pyh332efcf_0
# Linking babel-2.17.0-pyhd8ed1ab_0
# Linking gitdb-4.0.12-pyhd8ed1ab_0
# Linking markdown-it-py-4.0.0-pyhd8ed1ab_0
# Linking jupyterlab_pygments-0.3.0-pyhd8ed1ab_2
# Linking rfc3339-validator-0.1.4-pyhd8ed1ab_1
# Linking python-dateutil-2.9.0.post0-pyhe01879c_2
# Linking partd-1.4.2-pyhd8ed1ab_0
# Linking plotly-6.5.2-pyhd8ed1ab_0
# Linking mistune-3.2.0-pyhcf101f3_0
# Linking typer-slim-0.21.1-pyhcf101f3_0
# Linking exceptiongroup-1.3.1-pyhd8ed1ab_0
# Linking async-lru-2.1.0-pyhcf101f3_0
# Linking h11-0.16.0-pyhcf101f3_1
# Linking python-utils-3.9.1-pyhff2d567_1
# Linking typing-extensions-4.15.0-h396c80c_0
# Linking pydantic-1.10.22-pyh3cfb1c2_0
# Linking bleach-with-css-6.3.0-h5f6438b_0
# Linking fqdn-1.5.1-pyhd8ed1ab_1
# Linking email-validator-2.3.0-pyhd8ed1ab_0
# Linking lazy-loader-0.4-pyhd8ed1ab_2
# Linking gitpython-3.1.46-pyhd8ed1ab_0
# Linking rich-14.3.1-pyhcf101f3_0
# Linking arrow-1.4.0-pyhcf101f3_0
# Linking anyio-4.12.1-pyhcf101f3_0
# Linking ipython-8.37.0-pyh8f84b5b_0
# Linking uvicorn-0.40.0-pyhc90fa1f_0
# Linking progressbar2-4.5.0-pyhd8ed1ab_1
# Linking beautifulsoup4-4.14.3-pyha770c72_0
# Linking email_validator-2.3.0-hd8ed1ab_0
# Linking lazy_loader-0.4-pyhd8ed1ab_2
# Linking typer-slim-standard-0.21.1-h378290b_0
# Linking rich-toolkit-0.17.2-pyhcf101f3_0
# Linking isoduration-20.11.0-pyhd8ed1ab_1
# Linking httpcore-1.0.9-pyh29332c3_0
# Linking starlette-0.50.0-pyhfdc7a7d_0
# Linking typer-0.21.1-pyhf8876ea_0
# Linking httpx-0.28.1-pyhd8ed1ab_0
# Linking fastapi-core-0.125.0-pyhcf101f3_0
# Linking debugpy-1.8.20-py310h25320af_0
# Linking pyzmq-27.1.0-py310h4f33d48_0
# Linking websockets-16.0-py310h139afa4_1
# Linking uvloop-0.22.1-py310h7c4b9e2_1
# Linking httptools-0.7.1-py310h7c4b9e2_1
# Linking unicodedata2-17.0.0-py310h7c4b9e2_1
# Linking kiwisolver-1.4.9-py310haaf941d_2
# Linking rpds-py-0.30.0-py310hd8f68c5_0
# Linking protobuf-6.31.1-py310ha36e12e_2
# Linking backports.zstd-1.3.0-py310h69bd2ac_0
# Linking llvmlite-0.46.0-py310hee1c697_0
# Linking brotli-python-1.2.0-py310hba01987_1
# Linking pillow-12.1.0-py310h5a73078_0
# Linking lz4-4.4.5-py310hde1b0b5_1
# Linking psutil-7.2.2-py310h139afa4_0
# Linking msgpack-python-1.1.2-py310h03d9f68_1
# Linking markupsafe-3.0.3-py310h3406613_0
# Linking pyarrow-core-23.0.0-py310h923f568_0_cpu
# Linking numpy-1.26.4-py310hb13e2d6_0
# Linking frozendict-2.4.7-py310h7c4b9e2_0
# Linking tornado-6.5.4-py310ha78b2d2_0
# Linking pyyaml-6.0.3-py310h3406613_0
# Linking cffi-2.0.0-py310he7384ee_1
# Linking cytoolz-1.1.0-py310h7c4b9e2_1
# Linking blake3-1.0.8-py310hd8f68c5_1
# Linking watchfiles-1.1.1-py310hdfeec95_0
# Linking fonttools-4.61.1-py310h3406613_0
# Linking pyarrow-23.0.0-py310hff52083_0
# Linking h5py-3.15.1-nompi_py310h4aa865e_101
# Linking imagecodecs-lite-2019.12.3-py310h261611a_8
# Linking pyerfa-2.0.1.5-py310h32771cd_2
# Linking pywavelets-1.8.0-py310hf462985_0
# Linking scipy-1.15.2-py310h1d65ade_0
# Linking numba-0.63.1-py310h225f558_0
# Linking contourpy-1.3.2-py310h3788b33_0
# Linking pandas-2.3.3-py310h0158d43_2
# Linking watchdog-6.0.0-py310hff52083_2
# Linking argon2-cffi-bindings-25.1.0-py310h7c4b9e2_2
# Linking astropy-6.1.7-py310hf462985_0
# Linking matplotlib-base-3.10.8-py310hfde16b3_0
# Linking referencing-0.37.0-pyhcf101f3_0
# Linking urllib3-2.6.3-pyhd8ed1ab_0
# Linking jinja2-3.1.6-pyhcf101f3_1
# Linking imageio-2.37.0-pyhfb79c49_0
# Linking jupyter_client-8.8.0-pyhcf101f3_0
# Linking terminado-0.18.1-pyhc90fa1f_1
# Linking dask-core-2026.1.1-pyhcf101f3_1
# Linking uvicorn-standard-0.40.0-h4cd5af1_0
# Linking tifffile-2020.6.3-py_0
# Linking xarray-2025.6.1-pyhd8ed1ab_1
# Linking argon2-cffi-25.1.0-pyhd8ed1ab_0
# Linking jsonschema-specifications-2025.9.1-pyhcf101f3_0
# Linking requests-2.32.5-pyhcf101f3_1
# Linking branca-0.8.2-pyhd8ed1ab_0
# Linking bokeh-3.8.2-pyhd8ed1ab_0
# Linking pydeck-0.9.1-pyhd8ed1ab_0
# Linking ipykernel-7.1.0-pyha191276_0
# Linking jupyter_server_terminals-0.5.4-pyhcf101f3_0
# Linking distributed-2026.1.1-pyhcf101f3_1
# Linking fastapi-cli-0.0.20-pyhcf101f3_0
# warning  libmamba [fastapi-cli-0.0.20-pyhcf101f3_0] The following files were already present in the environment:
#     - bin/fastapi
# Linking jsonschema-4.26.0-pyhcf101f3_0
# Linking dask-2026.1.1-pyhcf101f3_0
# Linking fastapi-0.125.0-h149372e_0
# Linking nbformat-5.10.4-pyhd8ed1ab_1
# Linking jsonschema-with-format-nongpl-4.26.0-hcf101f3_0
# Linking altair-6.0.0-pyhd8ed1ab_1
# Linking nbclient-0.10.4-pyhd8ed1ab_0
# Linking jupyter_events-0.12.0-pyh29332c3_0
# Linking streamlit-1.53.1-pyhd8ed1ab_0
# Linking nbconvert-core-7.17.0-pyhcf101f3_0
# Linking jupyter_server-2.17.0-pyhcf101f3_0
# Linking jupyter-lsp-2.3.0-pyhcf101f3_0
# Linking notebook-shim-0.2.4-pyhd8ed1ab_1
# Linking jupyterlab_server-2.28.0-pyhcf101f3_0
# Linking jupyterlab-4.5.3-pyhd8ed1ab_0
# Linking notebook-7.5.3-pyhcf101f3_0
# Linking widgetsnbextension-3.6.10-pyhd8ed1ab_0
# Linking ipywidgets-7.8.5-pyhd8ed1ab_0
# Linking ipydatawidgets-4.3.2-pyhc268e32_0
# Linking ipywebrtc-0.6.0-pyhd8ed1ab_0
# Linking ipyvue-1.11.2-pyhd8ed1ab_0
# Linking bqplot-0.12.45-pyhe01879c_0
# Linking ipympl-0.10.0-pyhcf101f3_0
# Linking ipyleaflet-0.20.0-pyhd8ed1ab_0
# Linking pythreejs-2.4.2-pyhbbac1ac_1
# Linking ipyvuetify-1.11.3-pyhd8ed1ab_0
# Linking scikit-image-0.20.0-py310h9b08913_1
# Linking vaex-core-4.16.1-py310hc57749c_0
# Linking ipyvolume-0.6.3-pyhd8ed1ab_2
# Linking vaex-hdf5-0.14.1-pyhd8ed1ab_0
# Linking vaex-viz-0.5.4-pyhd8ed1ab_0
# Linking vaex-server-0.8.1-pyhd8ed1ab_0
# Linking vaex-ml-0.18.1-pyhd8ed1ab_0
# Linking vaex-astro-0.9.3-pyhd8ed1ab_0
# Linking vaex-jupyter-0.8.1-pyhd8ed1ab_0
# Linking vaex-4.16.0-pyhd8ed1ab_0
#
# Transaction finished
#
#
# To activate this environment, use:
#
#     micromamba activate vaexenv
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -n vaexenv mycommand
#
# vaex {'vaex-core': '4.16.1', 'vaex-viz': '0.5.4', 'vaex-hdf5': '0.14.1', 'vaex-server': '0.8.1', 'vaex-astro': '0.9.3', 'vaex-jupyter': '0.8.1', 'vaex-ml': '0.18.1'}
# pydantic 1.10.22
# yaml OK
# streamlit 1.53.1

# %%
# %%writefile app.py
import io
import traceback
import numpy as np
import pandas as pd
import streamlit as st
import plotly.express as px
import plotly.graph_objects as go
import vaex


# =========================
# Streamlit config
# =========================
st.set_page_config(page_title="Online Retail Analysis System", page_icon="📊", layout="wide")
st.title("📊 Online Retail Analysis System")
st.caption("Vaex + RFM Customer Segmentation (Colab, conda-forge, pydantic<2)")


# =========================
# Helpers
# =========================
CANON_COLS = ["InvoiceNo", "StockCode", "Description", "Quantity", "InvoiceDate", "UnitPrice", "CustomerID", "Country"]

def standardize_cols_pdf(pdf: pd.DataFrame) -> pd.DataFrame:
    rename_map = {}
    cols = set(pdf.columns)

    if "Invoice" in cols and "InvoiceNo" not in cols:
        rename_map["Invoice"] = "InvoiceNo"
    if "Customer ID" in cols and "CustomerID" not in cols:
        rename_map["Customer ID"] = "CustomerID"
    if "Price" in cols and "UnitPrice" not in cols:
        rename_map["Price"] = "UnitPrice"
    if "InvoiceDate" not in cols and "Invoice Date" in cols:
        rename_map["Invoice Date"] = "InvoiceDate"

    if rename_map:
        pdf = pdf.rename(columns=rename_map)

    return pdf


def load_with_pandas_then_vaex(file_bytes: bytes):
    """
    Robust loader:
    - pandas read CSV (stable parsing)
    - parse InvoiceDate safely
    - clean data
    - convert to Vaex
    """
    pdf = pd.read_csv(io.BytesIO(file_bytes), encoding="latin1")
    pdf = standardize_cols_pdf(pdf)

    required = ["InvoiceNo", "Quantity", "UnitPrice", "InvoiceDate"]
    missing = [c for c in required if c not in pdf.columns]
    if missing:
        raise ValueError(f"Thiếu cột bắt buộc: {missing}")

    # dtypes
    pdf["InvoiceNo"] = pdf["InvoiceNo"].astype(str)
    pdf["Quantity"] = pd.to_numeric(pdf["Quantity"], errors="coerce")
    pdf["UnitPrice"] = pd.to_numeric(pdf["UnitPrice"], errors="coerce")

    # parse InvoiceDate (format hay gặp: 12/1/2010 8:26)
    pdf["InvoiceDate"] = pd.to_datetime(
        pdf["InvoiceDate"].astype(str),
        errors="coerce",
        dayfirst=False,
        infer_datetime_format=True
    )

    # stats before clean
    raw_rows = len(pdf)

    # remove cancel invoices
    pdf = pdf[~pdf["InvoiceNo"].str.startswith("C")]

    # drop NA critical + invalid values
    pdf = pdf.dropna(subset=["InvoiceDate", "Quantity", "UnitPrice"])
    pdf = pdf[(pdf["Quantity"] > 0) & (pdf["UnitPrice"] > 0)]

    # revenue
    pdf["Revenue"] = pdf["Quantity"] * pdf["UnitPrice"]

    cleaned_rows = len(pdf)
    dropped = raw_rows - cleaned_rows

    # convert to Vaex
    vdf = vaex.from_pandas(pdf, copy_index=False)

    meta = {
        "raw_rows": raw_rows,
        "cleaned_rows": cleaned_rows,
        "dropped_rows": dropped,
        "min_date": pd.to_datetime(pdf["InvoiceDate"].min()),
        "max_date": pd.to_datetime(pdf["InvoiceDate"].max()),
    }
    return vdf, meta


def safe_top_n(pdf: pd.DataFrame, by: str, metric: str, n=10):
    if by not in pdf.columns or metric not in pdf.columns:
        return None
    out = (
        pdf.groupby(by, as_index=False)[metric]
        .sum()
        .sort_values(metric, ascending=False)
        .head(n)
    )
    return out


def compute_rfm(vdf: vaex.dataframe.DataFrame) -> pd.DataFrame:
    if "CustomerID" not in vdf.get_column_names():
        raise ValueError("Thiếu CustomerID để chạy RFM")

    ref_date = pd.to_datetime(vdf["InvoiceDate"].max())

    rfm = vdf.groupby(
        by="CustomerID",
        agg={
            "LastPurchase": vaex.agg.max("InvoiceDate"),
            "Frequency": vaex.agg.nunique("InvoiceNo"),
            "Monetary": vaex.agg.sum("Revenue"),
        }
    ).to_pandas_df()

    rfm["LastPurchase"] = pd.to_datetime(rfm["LastPurchase"])
    rfm["Recency"] = (ref_date - rfm["LastPurchase"]).dt.days

    # Score 1..5
    rfm["R"] = pd.qcut(rfm["Recency"], 5, labels=[5, 4, 3, 2, 1])
    rfm["F"] = pd.qcut(rfm["Frequency"].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])
    rfm["M"] = pd.qcut(rfm["Monetary"].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])

    rfm["RFM_Score"] = rfm["R"].astype(str) + rfm["F"].astype(str) + rfm["M"].astype(str)

    # Segments (rule-based, dễ thuyết trình)
    def segment(row):
        r, f, m = int(row["R"]), int(row["F"]), int(row["M"])
        if r >= 4 and f >= 4 and m >= 4:
            return "Champions"
        if r >= 4 and f >= 3:
            return "Loyal"
        if r >= 4 and f <= 2:
            return "New Customers"
        if r <= 2 and f >= 4:
            return "At Risk (High F)"
        if r <= 2 and m >= 4:
            return "At Risk (High M)"
        if r == 3 and f == 3:
            return "Potential Loyalist"
        return "Others"

    rfm["Segment"] = rfm.apply(segment, axis=1)

    return rfm.sort_values("Monetary", ascending=False)


# =========================
# Sidebar
# =========================
st.sidebar.header("Menu")
page = st.sidebar.radio(
    "Select Function:",
    ["Upload Data", "Data Quality", "EDA", "Visualization", "RFM Segmentation", "Conclusion"]
)

uploaded = st.sidebar.file_uploader("Upload Online Retail CSV", type=["csv"])

if "vdf" not in st.session_state:
    st.session_state.vdf = None
if "meta" not in st.session_state:
    st.session_state.meta = None


# =========================
# Load
# =========================
if uploaded:
    try:
        vdf, meta = load_with_pandas_then_vaex(uploaded.getvalue())
        st.session_state.vdf = vdf
        st.session_state.meta = meta
        st.success("Dataset loaded successfully (Vaex) ✅")
        st.caption(f"Rows: {len(vdf):,} | Date range: {meta['min_date']} → {meta['max_date']}")
        if meta["dropped_rows"] > 0:
            st.warning(f"Đã loại {meta['dropped_rows']:,} dòng lỗi/hoàn-huỷ/giá-trị âm hoặc thiếu.")
    except Exception as e:
        st.error(f"Load error: {e}")
        st.code(traceback.format_exc())
        st.stop()

vdf = st.session_state.vdf
meta = st.session_state.meta
if vdf is None:
    st.info("Upload CSV ở sidebar để bắt đầu.")
    st.stop()

# sample to display quickly (still big enough for charts)
pdf = vdf.head(300_000).to_pandas_df()
pdf["InvoiceDate"] = pd.to_datetime(pdf["InvoiceDate"], errors="coerce")


# =========================
# Pages
# =========================
if page == "Upload Data":
    st.subheader("1) Upload Data")
    c1, c2, c3, c4 = st.columns(4)
    c1.metric("Rows (clean)", f"{len(vdf):,}")
    c2.metric("Dropped rows", f"{meta['dropped_rows']:,}")
    c3.metric("Min date", str(meta["min_date"].date()))
    c4.metric("Max date", str(meta["max_date"].date()))
    st.write("Preview:")
    st.dataframe(pdf.head(50), use_container_width=True)

elif page == "Data Quality":
    st.subheader("2) Data Quality & Schema")

    cols_present = list(pdf.columns)
    st.write("**Columns detected:**")
    st.code(", ".join(cols_present))

    # Missing values
    miss = pdf.isna().mean().sort_values(ascending=False)
    miss_df = (miss * 100).round(2).reset_index()
    miss_df.columns = ["Column", "Missing_%"]
    st.write("**Missing rate (%):**")
    st.dataframe(miss_df, use_container_width=True)

    # Basic stats
    st.write("**Numeric summary (Quantity / UnitPrice / Revenue):**")
    num_cols = [c for c in ["Quantity", "UnitPrice", "Revenue"] if c in pdf.columns]
    st.dataframe(pdf[num_cols].describe().T, use_container_width=True)

    # Duplicates
    dup_inv = pdf.duplicated(subset=[c for c in ["InvoiceNo", "StockCode", "Quantity", "UnitPrice", "InvoiceDate"] if c in pdf.columns]).mean()
    st.info(f"Tỷ lệ dòng trùng theo (InvoiceNo, StockCode, Quantity, UnitPrice, InvoiceDate): **{dup_inv*100:.2f}%**")

elif page == "EDA":
    st.subheader("3) Exploratory Data Analysis (EDA)")

    # KPIs
    total_rev = float(np.nan_to_num(pdf["Revenue"].sum()))
    total_orders = int(pdf["InvoiceNo"].nunique()) if "InvoiceNo" in pdf.columns else 0
    total_customers = int(pdf["CustomerID"].nunique()) if "CustomerID" in pdf.columns else 0
    total_products = int(pdf["StockCode"].nunique()) if "StockCode" in pdf.columns else 0

    k1, k2, k3, k4 = st.columns(4)
    k1.metric("Total Revenue", f"{total_rev:,.2f}")
    k2.metric("Orders (unique invoices)", f"{total_orders:,}")
    k3.metric("Customers", f"{total_customers:,}")
    k4.metric("Products (StockCode)", f"{total_products:,}")

    st.divider()

    # Time series (monthly)
    pdf_ts = pdf.dropna(subset=["InvoiceDate"]).copy()
    pdf_ts["Month"] = pdf_ts["InvoiceDate"].dt.to_period("M").dt.to_timestamp()
    mrev = pdf_ts.groupby("Month", as_index=False)["Revenue"].sum().sort_values("Month")
    fig = px.line(mrev, x="Month", y="Revenue", markers=True, title="Monthly Revenue Trend")
    st.plotly_chart(fig, use_container_width=True)

    c1, c2 = st.columns(2)

    # Basket size distribution
    if "InvoiceNo" in pdf.columns:
        basket = pdf.groupby("InvoiceNo", as_index=False).agg(
            Items=("Quantity", "sum"),
            Lines=("InvoiceNo", "size"),
            Revenue=("Revenue", "sum"),
        )
        c1.plotly_chart(px.histogram(basket, x="Revenue", nbins=60, title="Order Revenue Distribution"), use_container_width=True)
        c2.plotly_chart(px.histogram(basket, x="Lines", nbins=60, title="Lines per Order Distribution"), use_container_width=True)

    st.divider()

    # Top countries
    if "Country" in pdf.columns:
        top_c = safe_top_n(pdf, "Country", "Revenue", 10)
        if top_c is not None:
            fig = px.bar(top_c, x="Revenue", y="Country", orientation="h", title="Top 10 Countries by Revenue")
            st.plotly_chart(fig, use_container_width=True)

    # Top products
    if "Description" in pdf.columns:
        top_p = safe_top_n(pdf, "Description", "Revenue", 15)
        if top_p is not None:
            fig = px.bar(top_p, x="Revenue", y="Description", orientation="h", title="Top Products by Revenue (Top 15)")
            st.plotly_chart(fig, use_container_width=True)

elif page == "Visualization":
    st.subheader("4) Visualization Dashboard")

    # Filters
    colA, colB, colC = st.columns([2, 2, 2])
    country_opt = sorted(pdf["Country"].dropna().unique().tolist()) if "Country" in pdf.columns else []
    sel_country = colA.selectbox("Filter Country (optional)", ["All"] + country_opt)

    min_d = pd.to_datetime(meta["min_date"]).date()
    max_d = pd.to_datetime(meta["max_date"]).date()
    sel_range = colB.date_input("Date range", value=(min_d, max_d), min_value=min_d, max_value=max_d)

    top_n = colC.slider("Top N", 5, 30, 10)

    dfv = pdf.copy()
    if sel_country != "All" and "Country" in dfv.columns:
        dfv = dfv[dfv["Country"] == sel_country]

    # date range filter
    if isinstance(sel_range, tuple) and len(sel_range) == 2:
        start, end = pd.to_datetime(sel_range[0]), pd.to_datetime(sel_range[1]) + pd.Timedelta(days=1) - pd.Timedelta(seconds=1)
        dfv = dfv[(dfv["InvoiceDate"] >= start) & (dfv["InvoiceDate"] <= end)]

    # Tabs
    t1, t2, t3 = st.tabs(["Revenue over time", "Top entities", "Price/Quantity"])

    with t1:
        dfv_ts = dfv.dropna(subset=["InvoiceDate"]).copy()
        dfv_ts["Day"] = dfv_ts["InvoiceDate"].dt.date
        drev = dfv_ts.groupby("Day", as_index=False)["Revenue"].sum()
        st.plotly_chart(px.line(drev, x="Day", y="Revenue", title="Daily Revenue"), use_container_width=True)

    with t2:
        c1, c2 = st.columns(2)

        if "CustomerID" in dfv.columns:
            top_cus = dfv.groupby("CustomerID", as_index=False)["Revenue"].sum().sort_values("Revenue", ascending=False).head(top_n)
            c1.plotly_chart(px.bar(top_cus, x="Revenue", y="CustomerID", orientation="h", title=f"Top {top_n} Customers by Revenue"), use_container_width=True)
        else:
            c1.info("Không có CustomerID.")

        if "Description" in dfv.columns:
            top_prod = dfv.groupby("Description", as_index=False)["Revenue"].sum().sort_values("Revenue", ascending=False).head(top_n)
            c2.plotly_chart(px.bar(top_prod, x="Revenue", y="Description", orientation="h", title=f"Top {top_n} Products by Revenue"), use_container_width=True)
        else:
            c2.info("Không có Description.")

        if "Country" in dfv.columns:
            top_ctry = dfv.groupby("Country", as_index=False)["Revenue"].sum().sort_values("Revenue", ascending=False).head(top_n)
            st.plotly_chart(px.pie(top_ctry, names="Country", values="Revenue", title=f"Revenue share (Top {top_n} Countries)"), use_container_width=True)

    with t3:
        c1, c2 = st.columns(2)
        if "UnitPrice" in dfv.columns:
            c1.plotly_chart(px.box(dfv, y="UnitPrice", title="UnitPrice (Boxplot)"), use_container_width=True)
        if "Quantity" in dfv.columns:
            c2.plotly_chart(px.box(dfv, y="Quantity", title="Quantity (Boxplot)"), use_container_width=True)

        st.plotly_chart(px.scatter(dfv.sample(min(len(dfv), 20000)), x="UnitPrice", y="Quantity", title="UnitPrice vs Quantity (sample)"),
                        use_container_width=True)

elif page == "RFM Segmentation":
    st.subheader("5) RFM Analysis (Customer Segmentation)")

    st.write("Chạy RFM trên **Vaex** (groupby nhanh) → xuất ra pandas để hiển thị/plot.")
    if st.button("Compute RFM"):
        try:
            rfm = compute_rfm(vdf)

            c1, c2, c3 = st.columns(3)
            c1.metric("Customers", f"{rfm['CustomerID'].nunique():,}")
            c2.metric("Avg Recency (days)", f"{rfm['Recency'].mean():.1f}")
            c3.metric("Avg Monetary", f"{rfm['Monetary'].mean():.2f}")

            st.dataframe(rfm.head(50), use_container_width=True)

            seg = rfm.groupby("Segment", as_index=False).agg(
                Customers=("CustomerID", "count"),
                Revenue=("Monetary", "sum"),
                AvgMonetary=("Monetary", "mean"),
                AvgRecency=("Recency", "mean"),
                AvgFrequency=("Frequency", "mean"),
            ).sort_values("Revenue", ascending=False)

            st.plotly_chart(px.bar(seg, x="Revenue", y="Segment", orientation="h", title="Revenue by Segment"),
                            use_container_width=True)
            st.plotly_chart(px.pie(seg, names="Segment", values="Customers", title="Customer distribution by Segment"),
                            use_container_width=True)

            st.download_button(
                "Download RFM CSV",
                rfm.to_csv(index=False).encode("utf-8"),
                "rfm_segmentation.csv",
                "text/csv"
            )
        except Exception as e:
            st.error(f"RFM error: {e}")
            st.code(traceback.format_exc())

elif page == "Conclusion":
    st.subheader("6) Conclusion & Insights")

    st.write("### Insight gợi ý (tự động theo logic dữ liệu)")
    st.write("- Doanh thu thường tập trung vào **một số sản phẩm/country/khách hàng** → ưu tiên tồn kho & marketing theo nhóm top.")
    st.write("- Revenue theo thời gian có thể có **mùa vụ** → tối ưu chiến dịch theo tháng/ngày.")
    st.write("- Đơn hàng có **outlier Quantity/UnitPrice** → kiểm tra data quality, hoàn/huỷ, sai giá.")
    st.write("- RFM giúp xác định **Champions / Loyal / At Risk** để retarget & giữ chân.")

    st.info("Nếu muốn nâng cấp tiếp: thêm Cohort Retention + Customer Lifetime Value (CLV) + Market Basket (Apriori).")
# Out:
# Writing app.py

# %%
# !pkill -f streamlit || true
# !./bin/micromamba run -n vaexenv python -m streamlit run app.py \
  --server.port 8501 --server.headless true --server.enableCORS false --server.enableXsrfProtection false \
  > streamlit.log 2>&1 &

# !sleep 2
# !lsof -i :8501 || true
# !tail -n 40 streamlit.log || true
# Out:
# ^C
# COMMAND  PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# python  4010 root   13u  IPv4 100636      0t0  TCP *:8501 (LISTEN)
# python  4010 root   14u  IPv6 100637      0t0  TCP *:8501 (LISTEN)
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.108.16:8501

# %%
# !./cloudflared tunnel --url http://127.0.0.1:8501 --loglevel info
# Out:
# 2026-01-31T14:23:48Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-01-31T14:23:48Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-01-31T14:23:52Z INF +--------------------------------------------------------------------------------------------+
# 2026-01-31T14:23:52Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-01-31T14:23:52Z INF |  https://newcastle-phrases-parenting-jesus.trycloudflare.com                               |
# 2026-01-31T14:23:52Z INF +--------------------------------------------------------------------------------------------+
# 2026-01-31T14:23:52Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-01-31T14:23:52Z INF Version 2026.1.2 (Checksum e157c54e929cc289cbd53860453168c2fe3439eb55e2e965a56579252585d9c1)
# 2026-01-31T14:23:52Z INF GOOS: linux, GOVersion: go1.24.11, GoArch: amd64
# 2026-01-31T14:23:52Z INF Settings: map[ha-connections:1 loglevel:info protocol:quic url:http://127.0.0.1:8501]
# 2026-01-31T14:23:52Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-01-31T14:23:52Z INF Generated Connector ID: 7aa2fdf3-73ee-4a42-9019-4e2b94e2e12e
# 2026-01-31T14:23:52Z INF Initial protocol quic
# 2026-01-31T14:23:52Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-01-31T14:23:52Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-01-31T14:23:52Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-01-31T14:23:52Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-01-31T14:23:52Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-01-31T14:23:52Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.27
# 2026/01/31 14:23:52 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-01-31T14:23:52Z INF Registered tunnel connection connIndex=0 connection=8383b443-3815-4b1e-8f9e-af8ec4fe1077 event=0 ip=198.41.192.27 location=lax07 protocol=quic
